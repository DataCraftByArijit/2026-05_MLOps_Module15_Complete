# %% [markdown]
# # Importing Libraries

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (3.13.0)
# Requirement already satisfied: mlflow-skinny==3.13.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.13.0)
# Requirement already satisfied: mlflow-tracing==3.13.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.13.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (6.0.5)
# Requirement already satisfied: Flask<4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: aiohttp<4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.13.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (1.18.4)
# Requirement already satisfied: cryptography<49,>=43.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (46.0.5)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<27 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (26.0.0)
# Requirement already satisfied: huey<4,>=2.5.4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.0.1)
# Requirement already satisfied: matplotlib<4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pandas<3 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (23.0.1)
# Requirement already satisfied: scikit-learn<2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: skops<1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow) (2.0.48)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (0.115.0)
# Requirement already satisfied: fastapi<1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (0.135.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (3.1.47)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<27 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (5.29.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (0.5.5)
# Requirement already satisfied: starlette<2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from mlflow-skinny==3.13.0->mlflow) (0.41.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.23.0)
# Requirement already satisfied: Mako in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from cryptography<49,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: blinker>=1.9.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.3.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: pycparser in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow) (2.52.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.13.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.13.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.13.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.13.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.13.0->mlflow) (0.60b1)
# Requirement already satisfied: wcwidth in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.13.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.13.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.13.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.13.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.13.0->mlflow) (2026.1.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from starlette<2->mlflow-skinny==3.13.0->mlflow) (4.12.1)
# Requirement already satisfied: h11>=0.8 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.13.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.13.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow) (0.4.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow) (0.6.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import mlflow
import os

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
mlflow.set_experiment("Loan_Status_Experiment")
# Out:
# <Experiment: artifact_location='/Users/shivam13juna/Documents/scaler/mlops/may_2026/may-2026-dsml-mlops/session_8_mlflow/mlruns/1', creation_time=1781056521411, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1781056521411, lifecycle_stage='active', name='Loan_Status_Experiment', tags={}, trace_location=None, workspace='default'>

# %%
train_df = pd.read_csv('data.csv')
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
train_df.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
# let's binary encode, Gender, Married Loan_Status

train_df['Gender'] = train_df['Gender'].map({'Male': 0, 'Female': 1})
train_df['Married'] = train_df['Married'].map({'No': 0, 'Yes': 1})
train_df['Loan_Status'] = train_df['Loan_Status'].map({'N': 0, 'Y': 1})

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 62.5+ KB

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## dropping all the missing values
train_df = train_df.dropna()
train_df.isnull().sum()


# Don't drop features off data off in production.
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Let's create simple Features

# %%
feature_columns = ['Gender', 'Married', 'ApplicantIncome', 'LoanAmount', 'CoapplicantIncome', 'Loan_Amount_Term', 'Credit_History']
X = train_df[feature_columns]
y = train_df.Loan_Status

# %%
mlflow.log_param("feature_columns", feature_columns)
# Out:
# ['Gender',
#  'Married',
#  'ApplicantIncome',
#  'LoanAmount',
#  'CoapplicantIncome',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# # Let's begin model training

# %%
from sklearn.ensemble import RandomForestClassifier

depth = 10
criteria = 'entropy'
n_esti = 10

#Will the bias increase or decrease if number of estimators increases?

mlflow.log_param("max_depth", depth)
mlflow.log_param("criterion", criteria)
mlflow.log_param("n_estimators", n_esti)
#mlflow.log_param("model_name", "RandomForestClassifier")
mlflow.log_param("model_name", "XgboostClassifier")
#mlflow.log_params({
#	"max_depth": depth,
#	"criterion": criteria,
#	"n_estimators": n_esti
#})

#model = RandomForestClassifier(max_depth=depth, random_state=5, criterion=criteria, n_estimators=n_esti)
#model.fit(X_train, y_train)


import xgboost as xgb
model = xgb.XGBClassifier(max_depth=depth, random_state=5, n_estimators=n_esti, use_label_encoder=False, eval_metric='logloss')
model.fit(X_train, y_train)
# Out:
# /Users/shivam13juna/Documents/virtual_envs/dev3.12/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [08:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import accuracy_score

pred_val = model.predict(X_val)
val_acc_score = accuracy_score(y_val, pred_val)

print(f"Training Accuracy: {model.score(X_train, y_train)}, Validation Accuracy: {val_acc_score}")
# Out:
# Training Accuracy: 0.9427083333333334, Validation Accuracy: 0.7708333333333334

# %%
mlflow.log_metric("train_accuracy", model.score(X_train, y_train))
mlflow.log_metric("val_accuracy", val_acc_score)

# %%
mlflow.end_run()

# %%
break
# Out:
#   Cell In[17], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# # Another efficient way to use MLflow

# %%
def mlflow_runs(n_est,max_dep,i):
    with mlflow.start_run():

        model_rf = RandomForestClassifier(n_estimators=n_est, max_depth=max_dep, random_state=5)
        model_rf.fit(X_train, y_train)

        pred_val = model_rf.predict(X_val)
        val_acc=accuracy_score(y_val, pred_val)

        pred_train = model_rf.predict(X_train)
        train_acc=accuracy_score(y_train, pred_train)

        run="hyperparameter_run_"+str(i)
        mlflow.set_tag('mlflow.runName',run)
        mlflow.log_param('n_estimators',n_est)
        mlflow.log_param('max_depth',max_dep)
        mlflow.log_param('model_name','RandomForestClassifier')
        mlflow.log_metric('val_acc',val_acc)
        mlflow.log_metric('train_acc',train_acc)
        mlflow.set_tag('data file','data_new.csv')

        mlflow.sklearn.log_model(model_rf, "model")


mlflow_runs(10,2,1)
mlflow_runs(20,2,2)
mlflow_runs(40,2,3)
mlflow_runs(10,4,4)
mlflow_runs(20,4,5)
mlflow_runs(40,4,6)
mlflow_runs(10,8,7)
mlflow_runs(20,8,8)
mlflow_runs(40,8,9)
# Out:
# 2026/06/10 07:48:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:43 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:48:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:47 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:48:50 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:50 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:48:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:52 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:48:55 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:55 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:48:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:48:57 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:49:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:49:00 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:49:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:49:02 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/10 07:49:05 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 07:49:05 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html

# %% [markdown]
# # Let's see how we can store a confusion matrix picture in MLflow.

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
import joblib


with mlflow.start_run():
	knn_model= KNeighborsClassifier(n_neighbors=5)
	knn_model.fit(X_train, y_train)

	pred_val = knn_model.predict(X_val)
	val_acc=accuracy_score(y_val, pred_val)

	pred_train = knn_model.predict(X_train)
	train_acc=accuracy_score(y_train, pred_train)

	run="KNN"
	mlflow.set_tag('mlflow.runName',run)
	mlflow.log_param('neighbors',5)
	mlflow.log_metric('val_acc',val_acc)
	mlflow.log_metric('train_acc',train_acc)
	mlflow.log_param('model_name','KNeighborsClassifier')

	cm=ConfusionMatrixDisplay.from_predictions( y_val,pred_val, cmap='Blues')
	cm.figure_.savefig('confusion_mat.png')
	mlflow.log_artifact('confusion_mat.png') # log_artifact can be used to log any file, of any format, e.g. images, text files, etc, with max-size of 5 GB. 

	# save dataframe as artifact

	mlflow.log_artifact('data.csv')

	mlflow.sklearn.log_model(knn_model, "model_knn")

	joblib.dump(knn_model, 'knn_model.joblib')
	mlflow.log_artifact('knn_model.joblib')
# Out:
# 2026/06/10 08:11:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 08:11:35 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
